# %%
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
from PIL import Image, ImageTk
import mysql.connector

# %%
class loginpage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        
        def clear():
            usernameEntry.delete(0,tk.END)
            passwordEntry.delete(0,tk.END)
        
        def login_user():
            if usernameEntry.get()=='' or passwordEntry.get()=='':
                messagebox.showerror('ERROR', 'All Fields are Required')
            else:
                query='SELECT * FROM register where email=%s and password=%s'
                cur.execute(query,(usernameEntry.get(),passwordEntry.get()))
                row=cur.fetchone()
                if row==None:
                    messagebox.showerror('ERROR','Invalid Username or Password')
                else:
                    messagebox.showinfo('WELCOME','Login Successful')
                    clear()
                    controller.show_frame(homepage)
        
        def hide():
            hide_eye.config(file='hide_eye.png')
            passwordEntry.config(show='*')
            eyeButton.config(command = show)

        def show():
            hide_eye.config(file='show_eye.png')
            passwordEntry.config(show='')

        load = Image.open('log.png')
        bgImage=ImageTk.PhotoImage(load)
        bgLabel = tk.Label(self, image = bgImage)
        bgLabel.image=bgImage
        bgLabel.grid(row=0, column=0)


        h1 = tk.Label(self,text = 'User Login', font = ('Noto Sans', 23, 'bold'), bg = 'white')
        h1.place(x=1150,y=150)

        #username
        lbl1 = tk.Label(self, text = 'Username', font = ('Noto Sans',11,'bold'), bg='white')
        lbl1.place(x=1075,y=220)
        usernameEntry = tk.Entry(self, width=35, font = ('Noto Sans',11,'bold'), bd = 0)
        usernameEntry.place(x=1075,y=250)
        #usernameEntry.insert(0,'Username')
        #usernameEntry.bind('<FocusIn>', user_enter)
        f1 = tk.Frame(self, width=300,height=2, bg = 'black')
        f1.place(x=1075,y=270)

        #password
        lbl2 = tk.Label(self, text = 'Password', font = ('Noto Sans',11,'bold'), bg='white')
        lbl2.place(x=1075,y=300)
        passwordEntry = tk.Entry(self, width=35, font = ('Noto Sans',11,'bold'), bd = 0, bg ='white', show="*")
        passwordEntry.place(x=1075,y=330)
        #passwordEntry.bind('<FocusIn>', password_enter)
        f2 = tk.Frame(self, width=300,height=2, bg = 'black')
        f2.place(x=1075,y=350)
        hide_eye = tk.PhotoImage(file = 'hide_eye.png')
        eyeButton = tk.Button(self, image = hide_eye, bd=0, bg='white', activebackground='white', cursor='hand2', command=show)
        eyeButton.place(x=1355, y=338)

        #Login Button
        loginButton=tk.Button(self, text='Login', font = ('Noto Sans',16,'bold'), cursor='hand2', width=8, bg='green',
                              command=lambda:login_user())
        loginButton.place(x=1165, y=420)
        f3 = tk.Frame(self, width=460,height=2, bg = 'black')
        f3.place(x=1000,y=520)

        signupLabel=tk.Label(self, text="Don't have an account?", font = ('Noto Sans',9,'bold'), bg='white')
        signupLabel.place(x=1210, y=570)

        newaccountButton=tk.Button(self, text='Register', font = ('Noto Sans',9, 'bold underline'), cursor='hand2', bd=0,
                                fg = 'blue', foreground='blue', bg='white', command=lambda: controller.show_frame(signuppage))
        newaccountButton.place(x=1350, y=570)
        
class signuppage(tk.Frame):
    
    
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        
        def clear():
            emailEntry.delete(0,tk.END)
            nameEntry.delete(0,tk.END)
            desEntry.delete(0,tk.END)
            passEntry.delete(0,tk.END)
            cpassEntry.delete(0,tk.END)
            check.set(0)
        
        def connect_db():
            if emailEntry.get()=='' or nameEntry.get()=='' or desEntry.get()=='' or passEntry.get()=='' or cpassEntry.get()=='':
                messagebox.showerror('ERROR', 'All Fields are Required')
            elif passEntry.get() != cpassEntry.get():
                 messagebox.showerror('ERROR','Password Mismatch')
            elif check.get()==0:
                 messagebox.showerror('ERROR','Please Accept the Terms & Conditions')
            else:
                cur.execute(f"SELECT * FROM register where email='{emailEntry.get()}'")
                row=cur.fetchone()
                if row!=None:
                    messagebox.showerror('ERROR','Email Id Already Registered!')
                else:
                    cur.execute(f"insert into register( email, name ,designation, password, cpassword) values ('{emailEntry.get()}','{nameEntry.get()}','{desEntry.get()}','{passEntry.get()}','{cpassEntry.get()}')")
                    con.commit()
                    messagebox.showinfo('SUCCESS','Registration Successful!')
                    clear()
        
        
        
        def signup():
            cur.execute(f"insert into register( email, name ,designation, password, cpassword) values ('{emailEntry.get()}','{nameEntry.get()}','{desEntry.get()}','{passEntry.get()}','{cpassEntry.get()}')")
            con.commit()
        
        def hidec():
            hide_eye1.config(file='hide_eye1.png')
            cpassEntry.config(show='*')
            eyeButton1.config(command = showc)

        def showc():
            hide_eye1.config(file='show_eye1.png')
            cpassEntry.config(show='')
            eyeButton1.config(command = hidec)

        def hide():
            hide_eye.config(file='hide_eye.png')
            passEntry.config(show='*')
            eyeButton.config(command = show)

        def show():
            hide_eye.config(file='show_eye.png')
            passEntry.config(show='')
            eyeButton.config(command = hide)
        load = Image.open('log.png')
        bgImage=ImageTk.PhotoImage(load)
        bgLabel = tk.Label(self, image = bgImage)
        bgLabel.image=bgImage
        bgLabel.grid(row=0, column=0)

        fframe=tk.Frame(self, bg='white')
        fframe.place(x=983,y=80)

        h1 = tk.Label(fframe,text = 'Create New Account', font = ('Times New Roman', 23, 'bold'), bg = 'white')
        h1.grid(row=0,column=0, padx=110, pady=50)

        lbl1 = tk.Label(fframe, text = 'Email', font = ('Noto Sans',11,'bold'), bg='white')
        lbl1.grid(row=1,column=0, sticky='w', padx=80)
        emailEntry = tk.Entry(fframe, width=40, font = ('Noto Sans',11,'bold'), bg='light green')
        emailEntry.grid(row=2,column=0)

        lbl2 = tk.Label(fframe, text = 'Name', font = ('Noto Sans',11,'bold'), bg='white')
        lbl2.grid(row=3,column=0, sticky='w', padx=80,pady=(10,0))
        nameEntry = tk.Entry(fframe, width=40, font = ('Noto Sans',11,'bold'), bg='light green')
        nameEntry.grid(row=4,column=0)

        lbl3 = tk.Label(fframe, text = 'Password', font = ('Noto Sans',11,'bold'), bg='white')
        lbl3.grid(row=7,column=0, sticky='w', padx=80,pady=(10,0))
        passEntry = tk.Entry(fframe, width=40, font = ('Noto Sans',11,'bold'), bg='light green', show='*')
        passEntry.grid(row=8,column=0)
        hide_eye = tk.PhotoImage(file = 'hide_eye.png')
        eyeButton = tk.Button(fframe, image = hide_eye, bd=0, bg='white', activebackground='white', cursor='hand2', command=show)
        eyeButton.place(x=390,y=340)

        lbl4 = tk.Label(fframe, text = 'Confirm Password', font = ('Noto Sans',11,'bold'), bg='white')
        lbl4.grid(row=9,column=0, sticky='w', padx=80,pady=(10,0))
        cpassEntry = tk.Entry(fframe, width=40, font = ('Noto Sans',11,'bold'), bg='light green', show='*')
        cpassEntry.grid(row=10,column=0)
        hide_eye1 = tk.PhotoImage(file = 'hide_eye1.png')
        eyeButton1 = tk.Button(fframe, image = hide_eye1, bd=0, bg='white', activebackground='white', cursor='hand2', command=showc)
        eyeButton1.place(x=390,y=395)

        lbl5 = tk.Label(fframe, text = 'Designation', font = ('Noto Sans',11,'bold'), bg='white')
        lbl5.grid(row=5,column=0, sticky='w', padx=80,pady=(10,0))
        desEntry = tk.Entry(fframe, width=40, font = ('Noto Sans',11,'bold'), bg='light green')
        desEntry.grid(row=6,column=0)

        check=tk.IntVar()
        tnc=tk.Checkbutton(fframe,text='I agree to the Terms & Conditions', font = ('Noto Sans',11,'bold'), bg='white', fg='black',variable=check)
        tnc.grid(row=11,column=0, pady=(15,0), sticky='w', padx=80)

        btn = tk.Button(fframe, text='Register', font = ('Noto Sans',16,'bold'), bg='firebrick1', cursor='hand2',command=connect_db)
        btn.grid(row=12,column=0, pady=(20,0), padx=80)

        lbl6 = tk.Label(fframe, text = 'Already have an account?', font = ('Noto Sans',11,'bold'), bg='white')
        lbl6.grid(row=13,column=0, padx=80,pady=(20,0))

        alreadyaccButton=tk.Button(fframe, text='Log In', font = ('Noto Sans',9, 'bold underline'), cursor='hand2', bd=0,
                                fg = 'blue', foreground='blue', bg='white', command=lambda: controller.show_frame(loginpage))
        alreadyaccButton.place(x=350,y=539)
        
        
class homepage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        
        load = Image.open('log.png')
        bgImage=ImageTk.PhotoImage(load)
        bgLabel = tk.Label(self, image = bgImage)
        bgLabel.image=bgImage
        bgLabel.grid(row=0, column=0)

        frame2=tk.Frame(self, bg='pink')
        frame2.place(x=983,y=80)

        lbl1=tk.Label(self, text='Welcome to Training & Placement', font=('', 28, 'bold'), bg='light green')
        lbl1.place(x=200,y=100)
        lbl2=tk.Label(self, text=' Management System', font=('', 28, 'bold'), bg='light green')
        lbl2.place(x=300,y=160)

        lbl3=tk.Label(frame2, text='Home Page', font=('', 28, 'bold'), bg='yellow')
        lbl3.grid(row=0,column=0, pady = 50)

        insertButton=tk.Button(frame2, text='Insert Candidate', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26, 
                               bg='green', command=lambda: controller.show_frame(insertpage))
        insertButton.grid(row=1, column=0, padx =(72,73), pady = (70,20))

        deleteButton=tk.Button(frame2, text='Delete Candidate', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26,
                               bg='green',command=lambda: controller.show_frame(deletepage))
        deleteButton.grid(row=2, column=0, padx =50, pady = (20,20))

        viewButton=tk.Button(frame2, text='View List of Candidate', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26,
                             bg='green', command=lambda: controller.show_frame(viewpage))
        viewButton.grid(row=3, column=0, padx =50, pady =(20,20))

        logoutButton=tk.Button(frame2, text='Logout', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26, bg='green',
                           command=lambda: controller.show_frame(loginpage))
        logoutButton.grid(row=4, column=0, padx =50, pady =(20,101))
        

class insertpage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        tk.Label(self,text="Student Registration Form (For Admin Only)", font="times 25 bold").grid(row=2,column=4)

        

        def insert():
            cur.execute(f"insert into student( fname , lname , uid , email_s , branch , gender , phoneno , ssc , hsc , diploma ,aggregateeng , statusp , company , offers , passout ) values ('{namef_box.get()}','{namel_box.get()}','{uid_box.get()}','{email_box.get()}','{branch_box.get()}','{gender_box.get()}','{phone_box.get()}','{SSCMarks_box.get()}','{HSCMarks_box.get()}','{Diploma_box.get()}','{Aggregate_box.get()}','{Status_box.get()}','{company_box.get()}','{offer_box.get()}','{batch_box.get()}')")
            con.commit()
            messagebox.showinfo('SUCCESS','Candidate Registered Successfully')
            
       
        '''selected = tk.StringVar()
        def selection(self,value):
            selected = gender_value.get()
            print(selected)
            #label.config(text=selected)  '''   
            
        namef_user = tk.Label(self,text="Student First Name",font=("15"))
        namef_user.grid(row=4,column=4)
        #namef_user.config(bg="#E59998")


        namel_user = tk.Label(self,text="Student Last Name",font=("15"))
        namel_user.grid(row=6,column=4)

        uid_user= tk.Label(self,text="UID of Student",font=("15"))
        uid_user.grid(row=8,column=4)

        email_user= tk.Label(self, text="Email Id",font=("15"))
        email_user.grid(row=10,column=4)

        branch_user= tk.Label(self,text="Branch",font=("15"))
        branch_user.grid(row=12,column=4)

        gender_user = tk.Label(self,text="Gender",font=("15"))
        gender_user.grid(row=14,column=4)

        phone_user=tk.Label(self,text="Phone No.",font=("15"))
        phone_user.grid(row=16,column=4)

        SSCMarks_user = tk.Label(self,text="SSC Marks",font=("15"))
        SSCMarks_user.grid(row=18,column=4)

        HSCMarks_user = tk.Label(self,text="HSC Marks",font=("15"))
        HSCMarks_user.grid(row=20,column=4)

        Diploma_user=tk.Label(self,text="Diploma Marks",font=("15"))
        Diploma_user.grid(row=22,column=4)
        
        Aggregate_user=tk.Label(self,text=" Engineering Aggregate Marks",font=("15"))
        Aggregate_user.grid(row=24,column=4)

        Status_user = tk.Label(self,text="Status of Placement",font=("15"))
        Status_user.grid(row=26,column=4)
        
        company_user = tk.Label(self,text="Placed Company Name",font=("15"))
        company_user.grid(row=28,column=4)
        
        offer_user = tk.Label(self,text="No. offers in current",font=("15"))
        offer_user.grid(row=30,column=4)
        
        batch_user = tk.Label(self,text="Passing out year",font=("15"))
        batch_user.grid(row=32,column=4)


        namef_value=tk.StringVar()
        namel_value=tk.StringVar()
        uid_value=tk.StringVar()
        email_value=tk.StringVar()
        branch_value=tk.StringVar()
        gender_value=tk.StringVar()
        phone_value=tk.StringVar()
        SSCMarks_value=tk.StringVar()
        HSCMarks_value=tk.StringVar()
        aggregate_value=tk.StringVar()
        Diploma_value=tk.StringVar()
        Status_value=tk.StringVar()
        company_value=tk.StringVar()
        offer_value=tk.StringVar()
        batch_value=tk.StringVar()
        #Domain_value=StringVar

        namef_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        namef_box.grid(row=4,column=6,padx=10,pady=10)
        namef_box.config(width=29)

        namel_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        namel_box.grid(row=6,column=6,padx=10,pady=10)
        namel_box.config(width=29)

        uid_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        uid_box.grid(row=8,column=6,padx=10,pady=10)
        uid_box.config(width=29)

        email_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        email_box.grid(row=10,column=6,padx=10,pady=10)
        email_box.config(width=29)
        
        branch_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        branch_box.grid(row=12,column=6,padx=10,pady=10)
        branch_box.config(width=29)

        #c=tk.StringVar()
        #list_of_Branch=[ '','Information Technology' ,'Computer Engineering' , 'Mechanical Engineering' ,'Civil Engineering' ,'Eelectrical Engineering','Electronics and Telecommunicatin']
        #branch_box = tk.OptionMenu(self, branch_value , *list_of_Branch)
        #branch_box.config(width=20)
        #branch_value.set("Select your Branch")
        #branch_box.grid(row=12,column=6,padx=10,pady=10)

        #gender_box = tk.Radiobutton(self,text="Male",textvariable=gender_value,value='Male',command=lambda: selection(gender_value.get()))
        #gender_box.grid(row=14,column=6,padx=10,pady=10)

        #gender_box = tk.Radiobutton(self,text="Female",textvariable=gender_value, value='Female' ,command=lambda:selection(gender_value.get()))
        #gender_box.grid(row=14,column=7,padx=10,pady=10)
        gender_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        gender_box.grid(row=14,column=6,padx=10,pady=10)
        gender_box.config(width=29)

        phone_box = tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        phone_box.grid(row=16,column=6,padx=10,pady=10)
        phone_box.config(width=29)

        SSCMarks_box=tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        SSCMarks_box.grid(row=18,column=6,padx=10,pady=10)
        SSCMarks_box.config(width=29)

        HSCMarks_box=tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        HSCMarks_box.grid(row=20,column=6,padx=10,pady=10)
        HSCMarks_box.config(width=29)

        Diploma_box=tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        Diploma_box.grid(row=22,column=6,padx=10,pady=10)
        Diploma_box.config(width=29)
        
        Aggregate_box=tk.Entry(self, width=40, font = ('Noto Sans',11,'bold'))
        Aggregate_box.grid(row=24,column=6,padx=10,pady=10)
        Aggregate_box.config(width=29)

        Status_box=tk.Entry(self,width=40, font = ('Noto Sans',11,'bold'))
        Status_box.grid(row=26,column=6,padx=10,pady=10)
        Status_box.config(width=29)
        
        company_box=tk.Entry(self,width=40, font = ('Noto Sans',11,'bold'))
        company_box.grid(row=28,column=6,padx=10,pady=10)
        company_box.config(width=29)
      
        offer_box=tk.Entry(self,width=40, font = ('Noto Sans',11,'bold'))
        offer_box.grid(row=30,column=6,padx=10,pady=10)
        offer_box.config(width=29)
        
        batch_box=tk.Entry(self,width=40, font = ('Noto Sans',11,'bold'))
        batch_box.grid(row=32,column=6,padx=10,pady=10)
        batch_box.config(width=29)

        backButton=tk.Button(self, text='Home', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(homepage))
        backButton.place(x=600,y=690)

        tk.Button(self,text="Submit", font = ('Times New Roman',18), cursor='hand2',width=8,command=insert).place(x=300,y=690)
        



class deletepage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        def show():
            
            cur.execute(f"SELECT fname,lname,uid,email_s,branch,gender,phoneno,ssc,hsc,diploma,statusp FROM student WHERE uid='{text_box.get()}'")
            r=cur.fetchall()
            global fname1
            global lname1
            global uid1
            global email_s1
            global branch1
            global gender1
            global statusp1
            
            num=2
            for i in r:
                fname1 =tk.Label(self,text=i[0],font="time 12 bold")
                fname1.grid(row=num,column=0,padx=20,pady=360)
                lname1 =tk.Label(self,text=i[1],font="time 12 bold")
                lname1.grid(row=num,column=1,padx=60,pady=360)
                uid1 =tk.Label(self,text=i[2],font="time 12 bold")
                uid1.grid(row=num,column=2,padx=15,pady=360)
                email_s1 =tk.Label(self,text=i[3],font="time 12 bold")
                email_s1.grid(row=num,column=3,padx=40,pady=360)
                branch1 =tk.Label(self,text=i[4],font="time 12 bold")
                branch1.grid(row=num,column=4,padx=55,pady=360)
                gender1 =tk.Label(self,text=i[5],font="time 12 bold")
                gender1.grid(row=num,column=5,padx=65,pady=360)
                    
                statusp1 =tk.Label(self,text=i[10],font="time 12 bold")
                statusp1.grid(row=num,column=10,padx=80,pady=340)
                
                num=num+1
            
            fname = tk.Label(self, text="fname",font=('Times New Roman',18,'bold'))
            fname.place(x=20,y=310)
            lname= tk.Label(self, text="lname",font=('Times New Roman',18,'bold'))
            lname.place(x=150,y=310)
            uid= tk.Label(self, text="uid",font=('Times New Roman',18,'bold'))
            uid.place(x=300,y=310)
            email_s = tk.Label(self, text="email_s",font=('Times New Roman',18,'bold'))
            email_s.place(x=430,y=310)
            branch = tk.Label(self, text="branch",font=('Times New Roman',18,'bold'))
            branch.place(x=660,y=310)
            gender = tk.Label(self, text="gender",font=('Times New Roman',18,'bold'))
            gender.place(x=820,y=310)
               
            statusp= tk.Label(self, text="Status",font=('Times New Roman',18,'bold'))
            statusp.place(x=970,y=310)
                
                
        def delete():
              
            sql = "DELETE FROM student WHERE uid =%s"
            #val = (uid, )
            cur.execute(sql,(text_box.get(),))
            con.commit()
            fname1.destroy()
            lname1.destroy()
            uid1.destroy()
            email_s1.destroy()
            branch1.destroy()
            gender1.destroy()
            statusp1.destroy()

           #query="delete from student where uid={}".format(uid)
           #c=self.con.cur()
           #cur.execute(query)
        uidEntry = tk.Label(self, text="UID:",font=('Times New Roman',21,'bold'))

        uidEntry = tk.Label(self, text="UID:",font=('Times New Roman',21,'bold'))
        uidEntry.place(x=30,y=100)
        #text_box = tk.Entry(self, width=40,font=('Times New Roman',21,'bold'))
        text_box = tk.Entry(self, width=40,font=('Times New Roman',21,'bold'),bg='white')

        #text_box = tk.Text(self, height=2, width=40)
        text_box.place(x=102, y=104)
        delete_button = tk.Button(self, text="Delete", font=('Times New Roman',18),width=8,command=delete)
        delete_button.place(x=100,y=150)
        show_button=tk.Button(self, text="Show", font=('Times New Roman',18),width=8,command=show)
        show_button.place(x=240,y=150)
        backButton=tk.Button(self, text='Home', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(homepage))
        backButton.place(x=170,y=250)
                
        
class viewpage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        lbl1 = tk.Label(self, text = 'View Candidate Information', font = ('Noto Sans',26,'bold'), bg='light blue')
        lbl1.place(x=550,y=100)
        f2 = tk.Frame(self, width=480,height=2, bg = 'black')
        f2.place(x=540,y=150)

        branchButton=tk.Button(self, text='View Registered Students', font = ('Noto Sans',16,'bold'), cursor='hand2',
                            width=26, bg='green', command=lambda: controller.show_frame(viewRegisteredCandidate))
        branchButton.place(x=400, y=300)

        percentButton=tk.Button(self, text='View Percentwise ', font = ('Noto Sans',16,'bold'), cursor='hand2',
                             width=26, bg='green', command=lambda: controller.show_frame(viewpercent))
        percentButton.place(x=800, y=300)

        statusButton=tk.Button(self, text='View Status (Placed/Unplaced)', font = ('Noto Sans',16,'bold'), cursor='hand2',
                            width=26, bg='green', command=lambda: controller.show_frame(viewstatus))
        statusButton.place(x=400, y=400)

        '''nofofferButton=tk.Button(self, text='View according to no. of offers', font = ('Noto Sans',16,'bold'), cursor='hand2',
                              width=26, bg='green', command=lambda: controller.show_frame(viewoffer))
        nofofferButton.place(x=400, y=500)'''
        
        UIDButton=tk.Button(self, text='View Candidate using UID', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26,
                         bg='green', command=lambda: controller.show_frame(viewuid))
        UIDButton.place(x=800, y=500)

        compButton=tk.Button(self, text='View Candidate Companywise', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26,
                          bg='green', command=lambda: controller.show_frame(viewcompany))
        compButton.place(x=400, y=500)
        
        batchButton=tk.Button(self, text='View Student Batchwise', font = ('Noto Sans',16,'bold'), cursor='hand2', width=26,
                         bg='green', command=lambda: controller.show_frame(viewbatch))
        batchButton.place(x=800, y=400)
        
        backButton=tk.Button(self, text='Home', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(homepage))
        backButton.place(x=720,y=680)

        self.configure(background = 'light blue')
        
             
        
class viewRegisteredCandidate(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        def showball():
            sall_window=tk.Tk()
            sall_window.geometry('1600x768')
            p1=tk.Label(sall_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=2, column=0,padx=10,pady=10)
            p2=tk.Label(sall_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=2, column=1,padx=10,pady=10)
            p3=tk.Label(sall_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=2, column=2,padx=10,pady=10)
            p4=tk.Label(sall_window,text='Branch', font = ('Noto Sans',16,'bold'))
            p4.grid(row=2, column=3,padx=10,pady=10)
            p5=tk.Label(sall_window,text='Company', font = ('Noto Sans',16,'bold'))
            p5.grid(row=2, column=4,padx=10,pady=10)
            p6=tk.Label(sall_window,text='Status', font = ('Noto Sans',16,'bold'))
            p6.grid(row=2, column=5,padx=10,pady=10)
        
            cur.execute(f"SELECT fname,lname,uid,branch,company,statusp FROM student WHERE branch='{branchEntry.get()}'")
            r=cur.fetchall()
            num=3
            for i in r:
                fname=tk.Label(sall_window,text=i[0])
                fname.grid(row=num,column=0,padx=10,pady=10)
                lname=tk.Label(sall_window,text=i[1])
                lname.grid(row=num,column=1,padx=10,pady=10)
                uid=tk.Label(sall_window,text=i[2])
                uid.grid(row=num,column=2,padx=10,pady=10)
                branch=tk.Label(sall_window,text=i[3])
                branch.grid(row=num,column=3,padx=10,pady=10)
                company=tk.Label(sall_window,text=i[4])
                company.grid(row=num,column=4,padx=10,pady=10)
                cstatus=tk.Label(sall_window,text=i[5])
                cstatus.grid(row=num,column=5,padx=10,pady=10)
                
                num=num+1
        def showall():
            all_window=tk.Tk()
            all_window.geometry('1600x768')
            p1=tk.Label(all_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=2, column=0,padx=10,pady=10)
            p2=tk.Label(all_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=2, column=1,padx=10,pady=10)
            p3=tk.Label(all_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=2, column=2,padx=10,pady=10)
            p4=tk.Label(all_window,text='Branch', font = ('Noto Sans',16,'bold'))
            p4.grid(row=2, column=3,padx=10,pady=10)
            p5=tk.Label(all_window,text='Company', font = ('Noto Sans',16,'bold'))
            p5.grid(row=2, column=4,padx=10,pady=10)
            p6=tk.Label(all_window,text='Status', font = ('Noto Sans',16,'bold'))
            p6.grid(row=2, column=5,padx=10,pady=10)
        
            cur.execute("SELECT fname,lname,uid,branch,company,statusp FROM student")
            r=cur.fetchall()
            num=3
            for i in r:
                fname=tk.Label(all_window,text=i[0])
                fname.grid(row=num,column=0,padx=10,pady=10)
                lname=tk.Label(all_window,text=i[1])
                lname.grid(row=num,column=1,padx=10,pady=10)
                uid=tk.Label(all_window,text=i[2])
                uid.grid(row=num,column=2,padx=10,pady=10)
                branch=tk.Label(all_window,text=i[3])
                branch.grid(row=num,column=3,padx=10,pady=10)
                company=tk.Label(all_window,text=i[4])
                company.grid(row=num,column=4,padx=10,pady=10)
                cstatus=tk.Label(all_window,text=i[5])
                cstatus.grid(row=num,column=5,padx=10,pady=10)
                
                num=num+1

        lbl1=tk.Label(self, text='View Registered Candidates',font = ('Noto Sans',26,'bold'))
        lbl1.place(x=550,y=20)

        viewall=tk.Button(self, text='All Students', font = ('Noto Sans',16,'bold'), cursor='hand2', width=15,command=showall)
        viewall.place(x=200, y=100)

        lbl2 = tk.Label(self, text = 'Branchwise', font = ('Noto Sans',16,'bold'))
        lbl2.place(x=800,y=100)
        branchEntry = tk.Entry(self, width=25, font = ('Noto Sans',16), bg ='white')
        branchEntry.place(x=950,y=100)
        viewbranch=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10, command=showball)
        viewbranch.place(x=1300, y=98)
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1100,y=20)

        self.configure(background = 'light blue')
        
class viewpercent(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        def show4per():
            vper_window=tk.Tk()
            vper_window.geometry('1600x768')
            p1 = tk.Label(vper_window, text="First Name",font = ('Noto Sans',14,'bold'))
            p1.grid(row=1,column=0,padx=10,pady=10)
            
            p2 = tk.Label(vper_window, text="Last Name",font = ('Noto Sans',14,'bold'))
            p2.grid(row=1,column=1,padx=10,pady=10)
            
            p3 = tk.Label(vper_window, text="UID",font = ('Noto Sans',14,'bold'))
            p3.grid(row=1,column=2,padx=10,pady=10)
            
            #p4 = Tk.Label(vper_window, text="Email id",font = ('Noto Sans',14,'bold'))
            #p4.grid(row=1,column=3,padx=10,pady=10)
            
            p5 = tk.Label(vper_window, text="Branch",font = ('Noto Sans',14,'bold'))
            p5.grid(row=1,column=3,padx=10,pady=10)
            
            #p6 = Tk.Label(vper_window, text="Gender",font = ('Noto Sans',14,'bold'))
            #p6.grid(row=1,column=5,padx=10,pady=10)
            
            #p7 = Tk.Label(vper_window, text="Phone No.",font = ('Noto Sans',14,'bold'))
            #p7.grid(row=1,column=6,padx=10,pady=10)
            
            p8 = tk.Label(vper_window, text="SSC",font = ('Noto Sans',14,'bold'))
            p8.grid(row=1,column=4,padx=10,pady=10)
            
            p9 = tk.Label(vper_window, text="HSC",font = ('Noto Sans',14,'bold'))
            p9.grid(row=1,column=5,padx=10,pady=10)
            
            p15 = tk.Label(vper_window, text="Diploma",font = ('Noto Sans',14,'bold'))
            p15.grid(row=1,column=6,padx=10,pady=10)
            
            p10 = tk.Label(vper_window, text="Engee. Aggregate",font = ('Noto Sans',14,'bold'))
            p10.grid(row=1,column=7,padx=10,pady=10)
            
            #p11 = Tk.Label(vper_window, text="Status",font = ('Noto Sans',14,'bold'))
            #p11.grid(row=1,column=10,padx=10,pady=10)
            
            #p12 = Tk.Label(vper_window, text="Company",font = ('Noto Sans',14,'bold'))
            #p12.grid(row=1,column=11,padx=10,pady=10)
            
            #p13 = tk.Label(vper_window, text="No. Offer",font = ('Noto Sans',14,'bold'))
            #p13.grid(row=1,column=12,padx=10,pady=10)
            
            p14 = tk.Label(vper_window, text="Passing Out",font = ('Noto Sans',14,'bold'))
            p14.grid(row=1,column=8,padx=10,pady=10)
            
            
            
            
            
            
            cur.execute(f"select fname,lname,uid,branch,ssc,hsc,diploma,aggregateeng,passout from student where ssc >= '{per10Entry.get()}' and hsc>='{per12Entry.get()}',diploma>= '{polEntry.get()}' and aggregateeng>='{perengEntry.get()}'")
            r=cur.fetchall()

            num=2
            for i in r:
                fname = tk.Label(vper_window, text=i[0],font = ('Noto Sans',14,'bold'))
                fname.grid(row=num,column=0,padx=10,pady=10)

                lname = tk.Label(vper_window, text=i[1],font = ('Noto Sans',14,'bold'))
                lname.grid(row=num,column=1,padx=10,pady=10)

                uid = tk.Label(vper_window, text=i[2],font = ('Noto Sans',14,'bold'))
                uid.grid(row=num,column=2,padx=10,pady=10)

                #emailgender_s = Tk.Label(vper_window, text=i[3],font = ('Noto Sans',14,'bold'))
                #email_s.grid(row=num,column=3,padx=10,pady=10)

                branch = tk.Label(vper_window, text=i[3],font = ('Noto Sans',14,'bold'))
                branch.grid(row=num,column=3,padx=10,pady=10)

                #gender= Tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                #gender.grid(row=num,column=5,padx=10,pady=10)

                #phoneno= Tk.Label(vper_window, text=i[6],font = ('Noto Sans',14,'bold'))
                #phoneno.grid(row=num,column=6,padx=10,pady=10)
                
                ssc = tk.Label(vper_window, text=i[4],font = ('Noto Sans',14,'bold'))
                ssc.grid(row=num,column=4,padx=10,pady=10)

                hsc = tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                hsc.grid(row=num,column=5,padx=10,pady=10)
                
                diploma = tk.Label(vper_window, text=i[6],font = ('Noto Sans',14,'bold'))
                diploma.grid(row=num,column=6,padx=10,pady=10)

                aggregateeng = tk.Label(vper_window, text=i[7],font = ('Noto Sans',14,'bold'))
                aggregateeng.grid(row=num,column=7,padx=10,pady=10)

                #statusp = Tk.Label(vper_window, text=i[10],font = ('Noto Sans',14,'bold'))
                #statusp.grid(row=num,column=10,padx=10,pady=10)

                #company = Tk.Label(vper_window, text=i[11],font = ('Noto Sans',14,'bold'))
                #company.grid(row=num,column=11,padx=10,pady=10)

                #offers = Tk.Label(vper_window, text=i[12],font = ('Noto Sans',14,'bold'))
                #offers.grid(row=num,column=12,padx=10,pady=10)

                passout = tk.Label(vper_window, text=i[8],font = ('Noto Sans',14,'bold'))
                passout.grid(row=num,column=8,padx=10,pady=10)

            

        def show3per():
            vper_window=tk.Tk()
            vper_window.geometry('1600x768')
            
            p1 = tk.Label(vper_window, text="First Name",font = ('Noto Sans',14,'bold'))
            p1.grid(row=1,column=0,padx=10,pady=10)
            
            p2 = tk.Label(vper_window, text="Last Name",font = ('Noto Sans',14,'bold'))
            p2.grid(row=1,column=1,padx=10,pady=10)
            
            p3 = tk.Label(vper_window, text="UID",font = ('Noto Sans',14,'bold'))
            p3.grid(row=1,column=2,padx=10,pady=10)
            
            #p4 = Tk.Label(vper_window, text="Email id",font = ('Noto Sans',14,'bold'))
            #p4.grid(row=1,column=3,padx=10,pady=10)
            
            p5 = tk.Label(vper_window, text="Branch",font = ('Noto Sans',14,'bold'))
            p5.grid(row=1,column=3,padx=10,pady=10)
            
            #p6 = Tk.Label(vper_window, text="Gender",font = ('Noto Sans',14,'bold'))
            #p6.grid(row=1,column=5,padx=10,pady=10)
            
            #p7 = Tk.Label(vper_window, text="Phone No.",font = ('Noto Sans',14,'bold'))
            #p7.grid(row=1,column=6,padx=10,pady=10)
            
            p8 = tk.Label(vper_window, text="SSC",font = ('Noto Sans',14,'bold'))
            p8.grid(row=1,column=4,padx=10,pady=10)
            
            #p9 = tk.Label(vper_window, text="HSC",font = ('Noto Sans',14,'bold'))
            #p9.grid(row=1,column=5,padx=10,pady=10)
            
            p15 = tk.Label(vper_window, text="Diploma",font = ('Noto Sans',14,'bold'))
            p15.grid(row=1,column=5,padx=10,pady=10)
            
            p10 = tk.Label(vper_window, text="Engee. Aggregate",font = ('Noto Sans',14,'bold'))
            p10.grid(row=1,column=6,padx=10,pady=10)
            
            #p11 = Tk.Label(vper_window, text="Status",font = ('Noto Sans',14,'bold'))
            #p11.grid(row=1,column=10,padx=10,pady=10)
            
            #p12 = Tk.Label(vper_window, text="Company",font = ('Noto Sans',14,'bold'))
            #p12.grid(row=1,column=11,padx=10,pady=10)
            
            #p13 = tk.Label(vper_window, text="No. Offer",font = ('Noto Sans',14,'bold'))
            #p13.grid(row=1,column=12,padx=10,pady=10)
            
            p14 = tk.Label(vper_window, text="Passing Out",font = ('Noto Sans',14,'bold'))
            p14.grid(row=1,column=7,padx=10,pady=10)
            
            
            
            
            
            
            cur.execute(f"select fname,lname,uid,branch,ssc,diploma,aggregateeng,passout from student where ssc >= '{per10Entry.get()}' and diploma>= '{polEntry.get()}' and aggregateeng>='{perengEntry.get()}'")
            r=cur.fetchall()

            num=2
            for i in r:
                fname = tk.Label(vper_window, text=i[0],font = ('Noto Sans',14,'bold'))
                fname.grid(row=num,column=0,padx=10,pady=10)

                lname = tk.Label(vper_window, text=i[1],font = ('Noto Sans',14,'bold'))
                lname.grid(row=num,column=1,padx=10,pady=10)

                uid = tk.Label(vper_window, text=i[2],font = ('Noto Sans',14,'bold'))
                uid.grid(row=num,column=2,padx=10,pady=10)

                #emailgender_s = Tk.Label(vper_window, text=i[3],font = ('Noto Sans',14,'bold'))
                #email_s.grid(row=num,column=3,padx=10,pady=10)

                branch = tk.Label(vper_window, text=i[3],font = ('Noto Sans',14,'bold'))
                branch.grid(row=num,column=3,padx=10,pady=10)

                #gender= Tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                #gender.grid(row=num,column=5,padx=10,pady=10)

                #phoneno= Tk.Label(vper_window, text=i[6],font = ('Noto Sans',14,'bold'))
                #phoneno.grid(row=num,column=6,padx=10,pady=10)
                
                ssc = tk.Label(vper_window, text=i[4],font = ('Noto Sans',14,'bold'))
                ssc.grid(row=num,column=4,padx=10,pady=10)

                #hsc = tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                #hsc.grid(row=num,column=5,padx=10,pady=10)
                
                diploma = tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                diploma.grid(row=num,column=5,padx=10,pady=10)

                aggregateeng = tk.Label(vper_window, text=i[6],font = ('Noto Sans',14,'bold'))
                aggregateeng.grid(row=num,column=6,padx=10,pady=10)

                #statusp = Tk.Label(vper_window, text=i[10],font = ('Noto Sans',14,'bold'))
                #statusp.grid(row=num,column=10,padx=10,pady=10)

                #company = Tk.Label(vper_window, text=i[11],font = ('Noto Sans',14,'bold'))
                #company.grid(row=num,column=11,padx=10,pady=10)

                #offers = Tk.Label(vper_window, text=i[12],font = ('Noto Sans',14,'bold'))
                #offers.grid(row=num,column=12,padx=10,pady=10)

                passout = tk.Label(vper_window, text=i[7],font = ('Noto Sans',14,'bold'))
                passout.grid(row=num,column=7,padx=10,pady=10)

                #fname = Tk.Label(vper_window, text=i[0],font = ('Noto Sans',14,'bold'))
                #name.grid(row=num,column=0,padx=10,pady=10)

                num=num+1



        def showper():
            vper_window=tk.Tk()
            vper_window.geometry('1600x768')
            
            p1 = tk.Label(vper_window, text="First Name",font = ('Noto Sans',14,'bold'))
            p1.grid(row=1,column=0,padx=10,pady=10)
            
            p2 = tk.Label(vper_window, text="Last Name",font = ('Noto Sans',14,'bold'))
            p2.grid(row=1,column=1,padx=10,pady=10)
            
            p3 = tk.Label(vper_window, text="UID",font = ('Noto Sans',14,'bold'))
            p3.grid(row=1,column=2,padx=10,pady=10)
            
            #p4 = Tk.Label(vper_window, text="Email id",font = ('Noto Sans',14,'bold'))
            #p4.grid(row=1,column=3,padx=10,pady=10)
            
            p5 = tk.Label(vper_window, text="Branch",font = ('Noto Sans',14,'bold'))
            p5.grid(row=1,column=3,padx=10,pady=10)
            
            #p6 = Tk.Label(vper_window, text="Gender",font = ('Noto Sans',14,'bold'))
            #p6.grid(row=1,column=5,padx=10,pady=10)
            
            #p7 = Tk.Label(vper_window, text="Phone No.",font = ('Noto Sans',14,'bold'))
            #p7.grid(row=1,column=6,padx=10,pady=10)
            
            p8 = tk.Label(vper_window, text="SSC",font = ('Noto Sans',14,'bold'))
            p8.grid(row=1,column=4,padx=10,pady=10)
            
            p9 = tk.Label(vper_window, text="HSC",font = ('Noto Sans',14,'bold'))
            p9.grid(row=1,column=5,padx=10,pady=10)
            
            p10 = tk.Label(vper_window, text="Engee. Aggregate",font = ('Noto Sans',14,'bold'))
            p10.grid(row=1,column=6,padx=10,pady=10)
            
            #p11 = Tk.Label(vper_window, text="Status",font = ('Noto Sans',14,'bold'))
            #p11.grid(row=1,column=10,padx=10,pady=10)
            
            #p12 = Tk.Label(vper_window, text="Company",font = ('Noto Sans',14,'bold'))
            #p12.grid(row=1,column=11,padx=10,pady=10)
            
            #p13 = tk.Label(vper_window, text="No. Offer",font = ('Noto Sans',14,'bold'))
            #p13.grid(row=1,column=12,padx=10,pady=10)
            
            p14 = tk.Label(vper_window, text="Passing Out",font = ('Noto Sans',14,'bold'))
            p14.grid(row=1,column=7,padx=10,pady=10)
            
            #p15 = Label(vper_window, text="First Name",font = ('Noto Sans',14,'bold'))
            #p15.grid(row=1,column=0,padx=10,pady=10)
            
            
            
            
            cur.execute(f"select fname,lname,uid,branch,ssc,hsc,aggregateeng,passout from student where ssc >= '{per10Entry.get()}' and hsc>= '{per12Entry.get()}' and aggregateeng>='{perengEntry.get()}'")
            r=cur.fetchall()

            num=2
            for i in r:
                fname = tk.Label(vper_window, text=i[0],font = ('Noto Sans',14,'bold'))
                fname.grid(row=num,column=0,padx=10,pady=10)

                lname = tk.Label(vper_window, text=i[1],font = ('Noto Sans',14,'bold'))
                lname.grid(row=num,column=1,padx=10,pady=10)

                uid = tk.Label(vper_window, text=i[2],font = ('Noto Sans',14,'bold'))
                uid.grid(row=num,column=2,padx=10,pady=10)

                #emailgender_s = Tk.Label(vper_window, text=i[3],font = ('Noto Sans',14,'bold'))
                #email_s.grid(row=num,column=3,padx=10,pady=10)

                branch = tk.Label(vper_window, text=i[3],font = ('Noto Sans',14,'bold'))
                branch.grid(row=num,column=3,padx=10,pady=10)

                #gender= Tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                #gender.grid(row=num,column=5,padx=10,pady=10)

                #phoneno= Tk.Label(vper_window, text=i[6],font = ('Noto Sans',14,'bold'))
                #phoneno.grid(row=num,column=6,padx=10,pady=10)
                
                ssc = tk.Label(vper_window, text=i[4],font = ('Noto Sans',14,'bold'))
                ssc.grid(row=num,column=4,padx=10,pady=10)

                hsc = tk.Label(vper_window, text=i[5],font = ('Noto Sans',14,'bold'))
                hsc.grid(row=num,column=5,padx=10,pady=10)

                aggregateeng = tk.Label(vper_window, text=i[6],font = ('Noto Sans',14,'bold'))
                aggregateeng.grid(row=num,column=6,padx=10,pady=10)

                #statusp = Tk.Label(vper_window, text=i[10],font = ('Noto Sans',14,'bold'))
                #statusp.grid(row=num,column=10,padx=10,pady=10)

                #company = Tk.Label(vper_window, text=i[11],font = ('Noto Sans',14,'bold'))
                #company.grid(row=num,column=11,padx=10,pady=10)

                #offers = Tk.Label(vper_window, text=i[12],font = ('Noto Sans',14,'bold'))
                #offers.grid(row=num,column=12,padx=10,pady=10)

                passout = tk.Label(vper_window, text=i[7],font = ('Noto Sans',14,'bold'))
                passout.grid(row=num,column=7,padx=10,pady=10)

                #fname = Tk.Label(vper_window, text=i[0],font = ('Noto Sans',14,'bold'))
                #name.grid(row=num,column=0,padx=10,pady=10)

                num=num+1



        lbl1=tk.Label(self, text='View Candidates Percentage',font = ('Noto Sans',26,'bold'))
        lbl1.place(x=550,y=20)


        # 10th+12th+Enginnering Aggregate

        lbl2 = tk.Label(self, text = '10th Percent', font = ('Noto Sans',14,'bold'))
        lbl2.place(x=200,y=100)
        per10Entry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        per10Entry.place(x=200,y=150)


        lbl3 = tk.Label(self, text = '12th Percent', font = ('Noto Sans',14,'bold'))
        lbl3.place(x=200,y=200)
        per12Entry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        per12Entry.place(x=200,y=250)


        lbl4 = tk.Label(self, text = 'Engineering Aggregate ', font = ('Noto Sans',14,'bold'))
        lbl4.place(x=200,y=300)
        perengEntry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        perengEntry.place(x=200,y=350)
        viewper10=tk.Button(self, text='Show', font = ('Noto Sans',10,'bold'), cursor='hand2', width=6,command=showper)
        viewper10.place(x=200, y=390)
        self.configure(background = 'light blue')
        
                

        #10th + Poly + Engineering

        lbl5 = tk.Label(self, text = '10th Percent', font = ('Noto Sans',14,'bold'))
        lbl5.place(x=600,y=100)
        per1Entry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        per1Entry.place(x=600,y=150)


        lbl6 = tk.Label(self, text = 'Poly Aggregtet', font = ('Noto Sans',14,'bold'))
        lbl6.place(x=600,y=200)
        polEntry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        polEntry.place(x=600,y=250)


        lbl7 = tk.Label(self, text = 'Engineering Aggregate ', font = ('Noto Sans',14,'bold'))
        lbl7.place(x=600,y=300)
        engEntry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        engEntry.place(x=600,y=350)
        viewper10=tk.Button(self, text='Show', font = ('Noto Sans',10,'bold'), cursor='hand2', width=6,command=show3per)
        viewper10.place(x=600, y=390)
    
         
    
        # 10th + 12th + Poly + Engineering

        lbl8 = tk.Label(self, text = '10th Percent', font = ('Noto Sans',14,'bold'))
        lbl8.place(x=1000,y=100)
        per101Entry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        per101Entry.place(x=1000,y=150)


        lbl9 = tk.Label(self, text = '12th Percent', font = ('Noto Sans',14,'bold'))
        lbl9.place(x=1000,y=200)
        per121Entry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        per121Entry.place(x=1000,y=250)


        lbl10 = tk.Label(self, text = 'Poly Aggregate', font = ('Noto Sans',14,'bold'))
        lbl10.place(x=1000,y=300)
        polyEntry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        polyEntry.place(x=1000,y=350)


        lbl11 = tk.Label(self, text = 'Engineering Aggregate ', font = ('Noto Sans',14,'bold'))
        lbl11.place(x=1000,y=400)
        engineEntry = tk.Entry(self, width=15, font = ('Noto Sans',14), bg ='white')
        engineEntry.place(x=1000,y=450)
        viewper10=tk.Button(self, text='Show', font = ('Noto Sans',10,'bold'), cursor='hand2', width=6,command=show4per)
        viewper10.place(x=1000, y=490)
        
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1100,y=20)

        self.configure(background = 'light blue')
        
class viewstatus(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        def showviewallp():
            allp_window=tk.Tk()
            allp_window.geometry('1600x768')
            p1=tk.Label(allp_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=2, column=0,padx=10,pady=10)
            p2=tk.Label(allp_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=2, column=1,padx=10,pady=10)
            p3=tk.Label(allp_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=2, column=2,padx=10,pady=10)
            p4=tk.Label(allp_window,text='Branch', font = ('Noto Sans',16,'bold'))
            p4.grid(row=2, column=4,padx=10,pady=10)
            p5=tk.Label(allp_window,text='Company', font = ('Noto Sans',16,'bold'))
            p5.grid(row=2, column=5,padx=10,pady=10)
        
            cur.execute("SELECT fname,lname,uid,branch,company FROM student where statusp='Placed'")
            r=cur.fetchall()
            num=3
            for i in r:
                fname=tk.Label(allp_window,text=i[0])
                fname.grid(row=num,column=0,padx=10,pady=10)
                lname=tk.Label(allp_window,text=i[1])
                lname.grid(row=num,column=1,padx=10,pady=10)
                uid=tk.Label(allp_window,text=i[2])
                uid.grid(row=num,column=2,padx=10,pady=10)
                branch=tk.Label(allp_window,text=i[3])
                branch.grid(row=num,column=3,padx=10,pady=10)
                company=tk.Label(allp_window,text=i[4])
                company.grid(row=num,column=4,padx=10,pady=10)
                
                num=num+1

        def showviewallup():
            allup_window=tk.Tk()
            allup_window.geometry('1600x768')
            p1=tk.Label(allup_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=2, column=0,padx=10,pady=10)
            p2=tk.Label(allup_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=2, column=1,padx=10,pady=10)
            p3=tk.Label(allup_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=2, column=2,padx=10,pady=10)
            p4=tk.Label(allup_window,text='Branch', font = ('Noto Sans',16,'bold'))
            p4.grid(row=2, column=4,padx=10,pady=10)
        
            cur.execute("SELECT fname,lname,uid,branch FROM student where statusp='Unplaced'")
            r=cur.fetchall()
            num=3
            for i in r:
                fname=tk.Label(allup_window,text=i[0])
                fname.grid(row=num,column=0,padx=10,pady=10)
                lname=tk.Label(allup_window,text=i[1])
                lname.grid(row=num,column=1,padx=10,pady=10)
                uid=tk.Label(allup_window,text=i[2])
                uid.grid(row=num,column=2,padx=10,pady=10)
                branch=tk.Label(allup_window,text=i[3])
                branch.grid(row=num,column=3,padx=10,pady=10)
                
                num=num+1

        def showplaced():
            brp_window=tk.Tk()
            brp_window.geometry('1600x768')
            p1=tk.Label(brp_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=2, column=0,padx=10,pady=10)
            p2=tk.Label(brp_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=2, column=1,padx=10,pady=10)
            p3=tk.Label(brp_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=2, column=2,padx=10,pady=10)
            p4=tk.Label(brp_window,text='Company', font = ('Noto Sans',16,'bold'))
            p4.grid(row=2, column=3,padx=10,pady=10)
        
            cur.execute(f"SELECT fname,lname,uid,company FROM student where statusp='Placed' and branch='{vapEntry.get()}'")
            r=cur.fetchall()
            num=3
            for i in r:
                fname=tk.Label(brp_window,text=i[0])
                fname.grid(row=num,column=0,padx=10,pady=10)
                lname=tk.Label(brp_window,text=i[1])
                lname.grid(row=num,column=1,padx=10,pady=10)
                uid=tk.Label(brp_window,text=i[2])
                uid.grid(row=num,column=2,padx=10,pady=10)
                company=tk.Label(brp_window,text=i[3])
                company.grid(row=num,column=3,padx=10,pady=10)
                
                num=num+1

        def showunplaced():
            brup_window=tk.Tk()
            brup_window.geometry('1600x768')
            p1=tk.Label(brup_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=10, column=0,padx=10,pady=10)
            p2=tk.Label(brup_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=10, column=1,padx=10,pady=10)
            p3=tk.Label(brup_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=10, column=2,padx=10,pady=10)
        
            cur.execute(f"SELECT fname,lname,uid FROM student where statusp='Unplaced' and branch='{vapEntry.get()}'")
            r=cur.fetchall()
            num=110
            for i in r:
                fname=tk.Label(brup_window,text=i[0])
                fname.grid(row=num,column=0,padx=10,pady=10)
                lname=tk.Label(brup_window,text=i[1])
                lname.grid(row=num,column=1,padx=10,pady=10)
                uid=tk.Label(brup_window,text=i[2])
                uid.grid(row=num,column=2,padx=10,pady=10)


        lbl1=tk.Label(self, text='View Status of Candidates',font = ('Noto Sans',26,'bold'), bg='light blue')
        lbl1.place(x=550,y=20)

        viewallp=tk.Button(self, text='All Placed Students', font = ('Noto Sans',11,'bold'), cursor='hand2', width=15, command=showviewallp)
        viewallp.place(x=700, y=200)

        viewallup=tk.Button(self, text='All Placed Unplaced Students', font = ('Noto Sans',11,'bold'), cursor='hand2', width=25,
                        command=showviewallup)
        viewallup.place(x=650, y=300)

        viewbranchp=tk.Label(self, text='Placed Student in following Branch', font = ('Noto Sans',11,'bold'))
        viewbranchp.place(x=500, y=400)
        vapEntry = tk.Entry(self, width=25, font = ('Noto Sans',16), bg ='white')
        vapEntry.place(x=800,y=400)
        viewp=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10, command=showplaced)
        viewp.place(x=1150, y=397)

        viewbranchup=tk.Label(self, text='Unplaced Student in following Branch', font = ('Noto Sans',11,'bold'))
        viewbranchup.place(x=500, y=500)
        vaupEntry = tk.Entry(self, width=25, font = ('Noto Sans',16), bg ='white')
        vaupEntry.place(x=800,y=500)
        viewup=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10, command=showunplaced)
        viewup.place(x=1150, y=497)
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1100,y=20)

        self.configure(background = 'light blue')
        
        
class viewoffer(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        lbl1=tk.Label(self, text='View According to Offers', font = ('Noto Sans',26,'bold'), bg='light blue')
        lbl1.place(x=550,y=20)

        lbl2=tk.Label(self, text='Students having offers above', font = ('Noto Sans',16,'bold'))
        lbl2.place(x=400,y=100)
        pkgEntry = tk.Entry(self, width=25, font = ('Noto Sans',16), bg ='white')
        pkgEntry.place(x=725,y=100)
        viewpkg=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10)
        #viewpkg.place(x=1050, ybrp_window)
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1100,y=20)

        self.configure(background = 'light blue')

        
class viewuid(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        def showuid():
            vuid_window=tk.Tk()
            vuid_window.geometry('1600x768')
            p1=tk.Label(vuid_window,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=10, column=3,padx=10,pady=10)
            p2=tk.Label(vuid_window,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=11, column=3,padx=10,pady=10)
            p3=tk.Label(vuid_window,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=12, column=3,padx=10,pady=10)
            p4=tk.Label(vuid_window,text='Branch', font = ('Noto Sans',16,'bold'))
            p4.grid(row=13, column=3,padx=10,pady=10)
            p5=tk.Label(vuid_window,text='Company', font = ('Noto Sans',16,'bold'))
            p5.grid(row=14, column=3,padx=10,pady=10)
            p6=tk.Label(vuid_window,text='Email', font = ('Noto Sans',16,'bold'))
            p6.grid(row=15, column=3,padx=10,pady=10)
            p7=tk.Label(vuid_window,text='SSC', font = ('Noto Sans',16,'bold'))
            p7.grid(row=16, column=3,padx=10,pady=10)
            p8=tk.Label(vuid_window,text='HSC', font = ('Noto Sans',16,'bold'))
            p8.grid(row=17, column=3,padx=10,pady=10)
            p9=tk.Label(vuid_window,text='Diploma', font = ('Noto Sans',16,'bold'))
            p9.grid(row=18, column=3,padx=10,pady=10)
            p10=tk.Label(vuid_window,text='Engineering', font = ('Noto Sans',16,'bold'))
            p10.grid(row=19, column=3,padx=10,pady=10)
            p11=tk.Label(vuid_window,text='Passout Batch', font = ('Noto Sans',16,'bold'))
            p11.grid(row=20, column=3,padx=10,pady=10)
                    
            cur.execute(f"SELECT fname,lname,uid,branch,company,email_s,ssc,hsc,diploma,aggregateeng,passout FROM student WHERE uid='{uidEntry.get()}'")
            r=cur.fetchall()
            
            for i in r:
                fname=tk.Label(vuid_window,text=i[0])
                fname.grid(row=10,column=4,padx=10,pady=10)
                lname=tk.Label(vuid_window,text=i[1])
                lname.grid(row=11,column=4,padx=10,pady=10)
                uid=tk.Label(vuid_window,text=i[2])
                uid.grid(row=12,column=4,padx=10,pady=10)
                branch=tk.Label(vuid_window,text=i[3])
                branch.grid(row=13,column=4,padx=10,pady=10)
                compi=tk.Label(vuid_window,text=i[4])
                compi.grid(row=14,column=4,padx=10,pady=10)
                email=tk.Label(vuid_window,text=i[5])
                email.grid(row=15,column=4,padx=10,pady=10)
                ssc=tk.Label(vuid_window,text=i[6])
                ssc.grid(row=16,column=4,padx=10,pady=10)
                hsc=tk.Label(vuid_window,text=i[7])
                hsc.grid(row=17,column=4,padx=10,pady=10)
                diploma=tk.Label(vuid_window,text=i[8])
                diploma.grid(row=18,column=4,padx=10,pady=10)
                aggregateeng=tk.Label(vuid_window,text=i[9])
                aggregateeng.grid(row=19,column=4,padx=10,pady=10)
                passou4=tk.Label(vuid_window,text=i[10])
                passou4.grid(row=20,column=4,padx=10,pady=10)

        lbl1=tk.Label(self, text='View Candidates using UID',font = ('Noto Sans',24,'bold'),bg='light blue')
        lbl1.place(x=550,y=20)

        lbl2 = tk.Label(self, text = 'UID', font = ('Noto Sans',16,'bold'),bg='light blue')
        lbl2.place(x=200,y=200)
        uidEntry = tk.Entry(self, width=20, font = ('Noto Sans',16), bg ='white')
        uidEntry.place(x=300,y=200)
        viewuid=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10, command=showuid)
        viewuid.place(x=600, y=197)
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1100,y=20)

        self.configure(background = 'light blue')
        
class viewcompany(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        
        def comp():
            compy=tk.Tk()
            compy.geometry('1600x768')
            p1=tk.Label(compy,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=10, column=3,padx=10,pady=10)
            p2=tk.Label(compy,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=10, column=4,padx=10,pady=10)
            p3=tk.Label(compy,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=10, column=5,padx=10,pady=10)
            p4=tk.Label(compy,text='Branch', font = ('Noto Sans',16,'bold'))
            p4.grid(row=10, column=6,padx=10,pady=10)
            p5=tk.Label(compy,text='Company', font = ('Noto Sans',16,'bold'))
            p5.grid(row=10, column=7,padx=10,pady=10)
                    
            cur.execute(f"SELECT fname,lname,uid,branch,company FROM student WHERE company='{pkgEntry.get()}'")
            r=cur.fetchall()
            num=11
            for i in r:
                fname=tk.Label(compy,text=i[0])
                fname.grid(row=num,column=3,padx=10,pady=10)
                lname=tk.Label(compy,text=i[1])
                lname.grid(row=num,column=4,padx=10,pady=10)
                uid=tk.Label(compy,text=i[2])
                uid.grid(row=num,column=5,padx=10,pady=10)
                branch=tk.Label(compy,text=i[3])
                branch.grid(row=num,column=6,padx=10,pady=10)
                compi=tk.Label(compy,text=i[4])
                compi.grid(row=num,column=7,padx=10,pady=10)
                    
        lbl1=tk.Label(self, text='View Students according to company', font = ('Noto Sans',26,'bold'), bg='light blue')
        lbl1.place(x=500,y=20)

        lbl2=tk.Label(self, text='Students placed in', font = ('Noto Sans',16,'bold'))
        lbl2.place(x=430,y=100)
        pkgEntry = tk.Entry(self, width=25, font = ('Noto Sans',16), bg ='white')
        pkgEntry.place(x=670,y=100)
        viewpkg=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10, command=comp)
        viewpkg.place(x=1000, y=98)
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1200,y=20)

        self.configure(background = 'light blue')        
class viewbatch(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        def showbatch():
            batch=tk.Tk()
            batch.geometry('1600x768')
            p1=tk.Label(batch,text='First Name', font = ('Noto Sans',16,'bold'))
            p1.grid(row=10, column=3,padx=10,pady=10)
            p2=tk.Label(batch,text='Last Name', font = ('Noto Sans',16,'bold'))
            p2.grid(row=10, column=4,padx=10,pady=10)
            p3=tk.Label(batch,text='UID', font = ('Noto Sans',16,'bold'))
            p3.grid(row=10, column=5,padx=10,pady=10)
            p4=tk.Label(batch,text='Email', font = ('Noto Sans',16,'bold'))
            p4.grid(row=10, column=6,padx=10,pady=10)
            p5=tk.Label(batch,text='Branch', font = ('Noto Sans',16,'bold'))
            p5.grid(row=10, column=7,padx=10,pady=10)
            p6=tk.Label(batch,text='Company', font = ('Noto Sans',16,'bold'))
            p6.grid(row=10, column=8,padx=10,pady=10)
        
            cur.execute(f"SELECT fname,lname,uid,email_s,branch,company FROM student where passout='{batchEntry.get()}'")
            r=cur.fetchall()
            num=11
            for i in r:
                fname=tk.Label(batch,text=i[0])
                fname.grid(row=num,column=3,padx=10,pady=10)
                lname=tk.Label(batch,text=i[1])
                lname.grid(row=num,column=4,padx=10,pady=10)
                uid=tk.Label(batch,text=i[2])
                uid.grid(row=num,column=5,padx=10,pady=10)
                email=tk.Label(batch,text=i[3])
                email.grid(row=num,column=6,padx=10,pady=10)
                branch=tk.Label(batch,text=i[4])
                branch.grid(row=num,column=7,padx=10,pady=10)
                company=tk.Label(batch,text=i[5])
                company.grid(row=num,column=8,padx=10,pady=10)
                
                num=num+1
                    
        lbl1=tk.Label(self, text='View Students Batchwise', font = ('Noto Sans',26,'bold'), bg='light blue')
        lbl1.place(x=500,y=20)

        lbl2=tk.Label(self, text='Passing Year', font = ('Noto Sans',16,'bold'))
        lbl2.place(x=430,y=100)
        batchEntry = tk.Entry(self, width=25, font = ('Noto Sans',16), bg ='white')
        batchEntry.place(x=670,y=100)
        
        viewbatch=tk.Button(self, text='Show', font = ('Noto Sans',12,'bold'), cursor='hand2', width=10, command=showbatch)
        viewbatch.place(x=1000, y=98)
        backButton=tk.Button(self, text='Back', font = ('Times New Roman',18), cursor='hand2',width=8, command=lambda: controller.show_frame(viewpage))
        backButton.place(x=1200,y=20)

        self.configure(background = 'light blue')
    
    
class Application(tk.Tk):
    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)

        window=tk.Frame(self)
        window.pack()
        window.grid_rowconfigure(0,minsize=500)
        window.grid_columnconfigure(0,minsize=800)
        self.frames={}
        for F in (loginpage,signuppage,homepage,insertpage,deletepage,viewpage,viewRegisteredCandidate,viewpercent,viewstatus,
                  viewoffer,viewuid,viewcompany,viewbatch):
            frame=F(window,self)
            self.frames[F]=frame
            frame.grid(row=0,column=0,sticky="nsew")
        self.show_frame(loginpage)
    def show_frame(self,page):
        frame=self.frames[page]
        frame.tkraise()
        
        
con = mysql.connector.connect(host="localhost" , user="root"  ,password="rahel@777")
cur = con.cursor(buffered=True)

try:
    cur.execute("use tnpms2")
except:
    cur.execute("create database tnpms2")
    cur.execute("use tnpms2")

try:
    cur.execute("describe register")
except:
    cur.execute("create table register( email varchar(30) primary key, name varchar(20),designation varchar(20), password varchar(15), cpassword varchar(30))")    
    
try:
    cur.execute("describe student")
except:
    cur.execute("create table student(fname varchar(20), lname varchar(20), uid varchar(15) primary key, email_s varchar(30), branch varchar(20), gender varchar(7), phoneno varchar(10), ssc varchar(5), hsc varchar(5), diploma varchar(5), aggregateeng varchar(5), statusp varchar(25), company varchar(15), offers varchar(25), passout varchar(10)   )")


app=Application()
app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Python 3.11\Lib\site-packages\mysql\connector\connection_cext.py:291, in CMySQLConnection._open_connection(self)
#     290 try:
# --> 291     self._cmysql.connect(**cnx_kwargs)
#     292     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 1368
#    1364         frame=self.frames[page]
#    1365         frame.tkraise()
# -> 1368 con = mysql.connector.connect(host="localhost" , user="root"  ,password="Janhvi123#")
#    1369 cur = con.cursor(buffered=True)
#    1371 try:
#
# ...
